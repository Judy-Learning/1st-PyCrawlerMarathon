# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
# 以HW8為例:知乎： https://www.zhihu.com/explore
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
# requests: 使 HTTP請求更簡單
import requests
url = 'https://www.zhihu.com/explore'
#要放 headers
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36"}
r = requests.get(url, headers = headers)
r.encoding = 'utf-8'
response = r.text
print('response_type: ', type(response))
print('\n')
print(response)
# Out:
# response_type:  <class 'str'>
#
#
# <!doctype html>
# ...

# %%
# Beautiful: 功能包括解析 HTML, XML文件、修復含有未閉合標籤等錯誤的文件。
#  用此挑出我們要的部分
from bs4 import BeautifulSoup
soup = BeautifulSoup(response, "html5lib")
#soup
# prettify()函數
#  將soup這個物件美化，soup就是的html_doc解析的結果，最後print將它印出來
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
posts = soup.find_all('a', class_='ExploreSpecialCard-title')
for post in posts:
    print(post.text)
# Out:
# 疫情是面镜子，照出世间百相
# 争议检测后，孙杨的 542 天
# 电影中她的 100 个瞬间
# 疫情下的新鲜事：万物皆可「云」

# %% [markdown]
# ## Grab + PyQuery

# %% [markdown]
# ### ModuleNotFoundError: No module named 'grab'
# ### sol: pip install Grab

# %%
pip install Grab
# Out:
# Processing c:\users\user.laptop-osidbp5e\appdata\local\pip\cache\wheels\42\37\49\63cd1902086963e8a9e169ca60d89326c9e24adb6ffcfd5d06\grab-0.6.41-py3-none-any.whl
# ...
#   Attempting uninstall: Grab
#     Found existing installation: grab 0.6.41
#     Uninstalling grab-0.6.41:
#       Successfully uninstalled grab-0.6.41
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: grab 0.6.41 requires selection, which is not installed.
# ERROR: grab 0.6.41 requires user-agent, which is not installed.
# ERROR: grab 0.6.41 requires weblib>=0.1.28, which is not installed.

# %%
from grab import Grab
g = Grab()
r_2 = g.go('https://www.zhihu.com/explore')#知乎網站
response_2 = r_2.body
print('response_2_type: ', type(response_2))#requests是'str'
print('\n')
print(response_2)
# Out:
# response_2_type:  <class 'bytes'>
#
#
# ...

# %% [markdown]
# ## PyQuery: 做解析

# %%
#### Error: ModuleNotFoundError: No module named 'pyquery'
#sol: pip install pyquery

# %%
pip install pyquery
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyquery import PyQuery as pq
doc = pq(response_2)
#print(doc)
title = doc('title')
print(type(title))
# print('\n')
print(title)

# 顯示標題
print(title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'>
# <title data-react-helmet="true">发现 - 知乎</title><title/>
# 发现 - 知乎

# %% [markdown]
# ### 列印class為object-1的標籤
# print(doc('.object-1'))
# #原文網址：https://kknews.cc/code/6qqlppp.html

# %% [markdown]
# ### 列印id為container的標籤
# print(doc('#container'))
# print(type(doc('#container')))
# 原文網址：https://kknews.cc/code/6qqlppp.html

# %%
a = doc('.ExploreSpecialCard-title')
#a.text()
for post in a:
    print(post.text)
# Out:
# 疫情如镜，照出世间百相
# 争议检测后，孙杨的 542 天
# 电影中她的 100 个瞬间
# 疫情下的新鲜事：万物皆可「云」
